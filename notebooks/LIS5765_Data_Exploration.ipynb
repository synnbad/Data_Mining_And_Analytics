# %% [markdown]
# <a href="https://colab.research.google.com/github/synnbad/Data_Mining_And_Analytics/blob/main/LIS5765_Data_Exploration_Sinbad_Adjuik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/diabetes.csv')
df.plot(kind='box',figsize=(20,20))
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.shape
# Out:
# (768, 9)

# %%
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df = df[df['SkinThickness'] <= 80]

# %%
df = df[df['Insulin'] <= 600]

# %%
df['Insulin'] = df['Insulin'].replace(0,df['Insulin'].median())

# %%
df.Age.hist()
# Out:
# <Axes: >

# %%
df.Age.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df["Age"].describe()
# Out:
# count    764.000000
# mean      33.185864
# std       11.701598
# min       21.000000
# 25%       24.000000
# 50%       29.000000
# 75%       41.000000
# max       81.000000
# Name: Age, dtype: float64

# %%
correlation=df.corr(method='pearson')
plt.figure(figsize=(16,10))
sns.heatmap(correlation, annot=True)
# Out:
# <Axes: >

# %%
sns.violinplot(x="Outcome", y='Pregnancies', data=df)
plt.show()

# %%
df.plot.scatter(x='SkinThickness', y='BMI')
sns.pairplot(data=df, hue="Outcome")
